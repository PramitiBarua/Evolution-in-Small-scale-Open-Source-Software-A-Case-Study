# %%
import os
commands = ""

# %%
directory = 'C:/Users/Mathius Barua/OneDrive - Bowling Green State University/CS_6640_Project_Pramiti/test'
my_num = 0
os.chdir('C:/Users/Mathius Barua/OneDrive - Bowling Green State University/CS_6640_Project_Pramiti/test')
#commands = f"{dirs} is read"
p = subprocess.Popen('dir',
                     shell=True,
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE)
for root, dirs, files in os.walk(directory):

#    if my_num == 0:
        
    for file in files:
        if file.endswith('.zip'): #and my_num < 2:
            no_zip = file.strip(".zip")
            xmlfile = no_zip + ".xml"
            print(xmlfile)
            print (file)
            cmd = ['srcml','--verbose', file,'-o',xmlfile]
            subprocess.call(cmd)
            print(cmd)
            my_num += 1
                
            text_file_class = no_zip + '_num_class' + ".csv"
            #print(text_file_class)
            text_file_function = no_zip + '_num_function'+ ".csv"
            #print(text_file_function)
            text_file_decl_stmt = no_zip + '_num_decl_stmt'+ ".csv"
            #print(text_file_decl_stmt)
            text_file_macros = no_zip + '_num_macros'+ ".csv"
            #print(text_file_macros)
            cmd1 = 'srcml --xpath=\"count(//src:class)\" ' + xmlfile + " -o " + text_file_class
            #print(cmd1)
            subprocess.call(cmd1)
            cmd2 = 'srcml --xpath=\"count(//src:function)\" ' + xmlfile + " -o " + text_file_function
            subprocess.call(cmd2)
            #print(cmd2)
            cmd3 = 'srcml --xpath=\"count(//src:decl_stmt)\" ' + xmlfile + " -o " + text_file_decl_stmt
            subprocess.call(cmd3)
            #print(cmd3)
            cmd4 = 'srcml --xpath=\"count(//cpp:define)\" ' + xmlfile + " -o " + text_file_macros
            subprocess.call(cmd4)
            #print(cmd4)
# Out:
# aseprite-1.0.0.xml
# aseprite-1.0.0.zip
# ['srcml', '--verbose', 'aseprite-1.0.0.zip', '-o', 'aseprite-1.0.0.xml']
# aseprite-1.0.3.xml
# aseprite-1.0.3.zip
# ['srcml', '--verbose', 'aseprite-1.0.3.zip', '-o', 'aseprite-1.0.3.xml']

# %%
import os

# %%
directory = 'C:/Users/JoeKa/OneDrive - Bowling Green State University/CS_6640_Project_Pramiti/all_files/terminal'
os.chdir('C:/Users/JoeKa/OneDrive - Bowling Green State University/CS_6640_Project_Pramiti/all_files/terminal')
for root, dirs, files in os.walk(directory):
    
        
    for file in files:
       
        if file.endswith('.txt'): #and my_num < 2:
            
            if "cloc" in file:
                with open("c_total.txt", "a") as r:
                    r.write(file)
                    r.write('\n')
                    
                with open("c_total_num_f.txt", "a") as r:
 
                    with open(file) as f:
                        lines = f.read().splitlines()
                        for line in lines:
                            count = 0
                            for word in line.split():
                                if word == "SUM:":
                                    count += 1
                                elif count >= 1 and count < 2:
                                    print(word)
                                    r.write(str(word))
                                    r.write('\n')
                                    count += 1
                    f.close()
            if "cloc" in file:  
                with open("c_total_num_bnk.txt", "a") as r:
                    with open(file) as f:   
                        lines = f.read().splitlines()
                        for line in lines:
                            count = 0
                            for word in line.split():
                                if word == "SUM:":
                                    count += 1
                                elif count >= 1 and count < 2:
                                    count += 1
                                    #r.write(str(word))
                                elif count >= 2 and count < 3:
                                    r.write(str(word))
                                    r.write('\n')
                                    count += 1
                    f.close()
            if "cloc" in file:
                    
                with open("c_total_num_cmt.txt", "a") as r:

                    with open(file) as f:
                         
                        lines = f.read().splitlines()
                       
                    
                        for line in lines:
                            #if "SUM" in line:
                            #    print(line)
                            count = 0
                            for word in line.split():
                                
                                #print(word)
                                if word == "SUM:":
                                    count += 1
                                elif count >= 1 and count < 2:
                                    count += 1
                                elif count >= 2 and count < 3:
                                    count += 1
                                elif count >= 3 and count < 4:
                                    r.write(str(word))
                                    r.write('\n')
                                    count += 1
                    f.close()
                                    
            if "cloc" in file:
                    
                with open("c_total_num_cd.txt", "a") as r:
                    with open(file) as f: 
                        lines = f.read().splitlines()
                        for line in lines:
                            count = 0
                            for word in line.split():
                                
                                if word == "SUM:":
                                    count += 1
                                elif count >= 1 and count < 2:
                                    count += 1   
                                elif count >= 2 and count < 3:
                                    count += 1
                                elif count >= 3 and count < 4:
                                    count += 1
                                elif count >= 4 and count < 5:
                                    r.write(str(word))
                                    r.write('\n')
                                    count += 1
                    f.close()
# Out:
# 1296
# 1296
# 1341
# 1341
# 1347
# 1354
# 1040
# 1040
# 1093
# 1093
# 1123
# 1150
# 1151
# 1154
# 1166
# 1182
# 1182
# 1182
# 1225
# 1225
# 1270
# 1354
# 1359
# 1388
# 1388
# 1392
# 1392
# 2286
# 2288
# 2288
# 2294
# 2295
# 2295
# 2298
# 2315
# 2315
# 2318
# 1414
# 1414
# 1414
# 1448
# 1449
# 1464
# 1461
# 1461
# 1501
# 1501
# 1501
# 1501
# 2078
# 2078
# 2078
# 2115
# 2115
# 2119
# 2151
# 2151
# 2207
# 2224
# 24
# 36
# 66

# %%
with open("test_file", "w") as f:
    for i in range(10):
        f.write(i)

# %%
    with open('aggregate_TEST.txt', 'w') as r:
        
        for file in files:
       
            if file.endswith('.txt'): #and my_num < 2:
                with open(file) as f:
                    if "class" in file:
                        r.write(file)    
                        lines = f.read().splitlines()
                        r.write('\n')
                        aggr = 0

                        for line in lines:
                            curr = int(line)
                            aggr += curr      
                        r.write(str(aggr))
                        r.write('\n')
                   
                        #print(aggr)
                f.close()
    r.close()
