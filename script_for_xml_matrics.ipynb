# %%
import os, subprocess, shlex
commands = ""

# %%
directory = 'F:/OneDrive - Bowling Green State University/CS_6640_Project_Pramiti - Joseph K Blankenships files/all_files/clickhouse'
my_num = 0
os.chdir('F:/OneDrive - Bowling Green State University/CS_6640_Project_Pramiti - Joseph K Blankenships files/all_files/clickhouse')
#commands = f"{dirs} is read"
p = subprocess.Popen('dir',
                     shell=True,
                     stdout=subprocess.PIPE, 
                     stderr=subprocess.PIPE)
for root, dirs, files in os.walk(directory):

#    if my_num == 0:
        
    for file in files:
        if file.endswith('.zip'): #and my_num < 2:
            no_zip = file.strip(".zip")
            xmlfile = no_zip + ".xml"
            print(xmlfile)
            print (file)
            cmd = ['srcml','--verbose', file,'-o',xmlfile]
            subprocess.call(cmd)
            print(cmd)
            my_num += 1
                
            text_file_class = no_zip + '_num_class' + ".txt"
            #print(text_file_class)
            text_file_function = no_zip + '_num_function'+ ".txt"
            #print(text_file_function)
            text_file_decl_stmt = no_zip + '_num_decl_stmt'+ ".txt"
            #print(text_file_decl_stmt)
            text_file_macros = no_zip + '_num_macros'+ ".txt"
            #print(text_file_macros)
            cmd1 = 'srcml --xpath=\"count(//src:class)\" ' + xmlfile + " -o " + text_file_class
            #print(cmd1)
            subprocess.call(cmd1)
            cmd2 = 'srcml --xpath=\"count(//src:function)\" ' + xmlfile + " -o " + text_file_function
            subprocess.call(cmd2)
            #print(cmd2)
            cmd3 = 'srcml --xpath=\"count(//src:decl_stmt)\" ' + xmlfile + " -o " + text_file_decl_stmt
            subprocess.call(cmd3)
            #print(cmd3)
            cmd4 = 'srcml --xpath=\"count(//cpp:define)\" ' + xmlfile + " -o " + text_file_macros
            subprocess.call(cmd4)
            #print(cmd4)
# Out:
# ClickHouse-20.10.2.20-stable.xml
# ClickHouse-20.10.2.20-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.10.2.20-stable.zip', '-o', 'ClickHouse-20.10.2.20-stable.xml']
# ClickHouse-20.10.3.30-stable.xml
# ClickHouse-20.10.3.30-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.10.3.30-stable.zip', '-o', 'ClickHouse-20.10.3.30-stable.xml']
# ClickHouse-20.10.4.1-stable.xml
# ClickHouse-20.10.4.1-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.10.4.1-stable.zip', '-o', 'ClickHouse-20.10.4.1-stable.xml']
# ClickHouse-20.10.6.27-stable.xml
# ClickHouse-20.10.6.27-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.10.6.27-stable.zip', '-o', 'ClickHouse-20.10.6.27-stable.xml']
# ClickHouse-20.10.7.4-stable.xml
# ClickHouse-20.10.7.4-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.10.7.4-stable.zip', '-o', 'ClickHouse-20.10.7.4-stable.xml']
# ClickHouse-20.11.2.1-stable.xml
# ClickHouse-20.11.2.1-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.11.2.1-stable.zip', '-o', 'ClickHouse-20.11.2.1-stable.xml']
# ClickHouse-20.11.3.3-stable.xml
# ClickHouse-20.11.3.3-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.11.3.3-stable.zip', '-o', 'ClickHouse-20.11.3.3-stable.xml']
# ClickHouse-20.11.4.13-stable.xml
# ClickHouse-20.11.4.13-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.11.4.13-stable.zip', '-o', 'ClickHouse-20.11.4.13-stable.xml']
# ClickHouse-20.11.5.18-stable.xml
# ClickHouse-20.11.5.18-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.11.5.18-stable.zip', '-o', 'ClickHouse-20.11.5.18-stable.xml']
# ClickHouse-20.11.6.6-stable.xml
# ClickHouse-20.11.6.6-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.11.6.6-stable.zip', '-o', 'ClickHouse-20.11.6.6-stable.xml']
# ClickHouse-20.11.7.16-stable.xml
# ClickHouse-20.11.7.16-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.11.7.16-stable.zip', '-o', 'ClickHouse-20.11.7.16-stable.xml']
# ClickHouse-20.12.2.1-stable.xml
# ClickHouse-20.12.2.1-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.12.2.1-stable.zip', '-o', 'ClickHouse-20.12.2.1-stable.xml']
# ClickHouse-20.12.3.3-stable.xml
# ClickHouse-20.12.3.3-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.12.3.3-stable.zip', '-o', 'ClickHouse-20.12.3.3-stable.xml']
# ClickHouse-20.12.4.5-stable.xml
# ClickHouse-20.12.4.5-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.12.4.5-stable.zip', '-o', 'ClickHouse-20.12.4.5-stable.xml']
# ClickHouse-20.12.5.18-stable.xml
# ClickHouse-20.12.5.18-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.12.5.18-stable.zip', '-o', 'ClickHouse-20.12.5.18-stable.xml']
# ClickHouse-20.12.7.3-stable.xml
# ClickHouse-20.12.7.3-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.12.7.3-stable.zip', '-o', 'ClickHouse-20.12.7.3-stable.xml']
# ClickHouse-20.12.8.5-stable.xml
# ClickHouse-20.12.8.5-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.12.8.5-stable.zip', '-o', 'ClickHouse-20.12.8.5-stable.xml']
# ClickHouse-20.6.10.2-stable.xml
# ClickHouse-20.6.10.2-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.6.10.2-stable.zip', '-o', 'ClickHouse-20.6.10.2-stable.xml']
# ClickHouse-20.6.11.1-stable.xml
# ClickHouse-20.6.11.1-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.6.11.1-stable.zip', '-o', 'ClickHouse-20.6.11.1-stable.xml']
# ClickHouse-20.6.8.5-stable.xml
# ClickHouse-20.6.8.5-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.6.8.5-stable.zip', '-o', 'ClickHouse-20.6.8.5-stable.xml']
# ClickHouse-20.6.9.1-stable.xml
# ClickHouse-20.6.9.1-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.6.9.1-stable.zip', '-o', 'ClickHouse-20.6.9.1-stable.xml']
# ClickHouse-20.7.4.11-stable.xml
# ClickHouse-20.7.4.11-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.7.4.11-stable.zip', '-o', 'ClickHouse-20.7.4.11-stable.xml']
# ClickHouse-20.8.19.4-stable.xml
# ClickHouse-20.8.19.4-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.8.19.4-stable.zip', '-o', 'ClickHouse-20.8.19.4-stable.xml']
# ClickHouse-20.9.3.45-stable.xml
# ClickHouse-20.9.3.45-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.9.3.45-stable.zip', '-o', 'ClickHouse-20.9.3.45-stable.xml']
# ClickHouse-20.9.4.76-stable.xml
# ClickHouse-20.9.4.76-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.9.4.76-stable.zip', '-o', 'ClickHouse-20.9.4.76-stable.xml']
# ClickHouse-20.9.5.5-stable.xml
# ClickHouse-20.9.5.5-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.9.5.5-stable.zip', '-o', 'ClickHouse-20.9.5.5-stable.xml']
# ClickHouse-20.9.6.14-stable.xml
# ClickHouse-20.9.6.14-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.9.6.14-stable.zip', '-o', 'ClickHouse-20.9.6.14-stable.xml']
# ClickHouse-20.9.7.11-stable.xml
# ClickHouse-20.9.7.11-stable.zip
# ['srcml', '--verbose', 'ClickHouse-20.9.7.11-stable.zip', '-o', 'ClickHouse-20.9.7.11-stable.xml']
# ClickHouse-21.1.2.15-stable.xml
# ClickHouse-21.1.2.15-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.1.2.15-stable.zip', '-o', 'ClickHouse-21.1.2.15-stable.xml']
# ClickHouse-21.1.4.46-stable.xml
# ClickHouse-21.1.4.46-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.1.4.46-stable.zip', '-o', 'ClickHouse-21.1.4.46-stable.xml']
# ClickHouse-21.1.5.4-stable.xml
# ClickHouse-21.1.5.4-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.1.5.4-stable.zip', '-o', 'ClickHouse-21.1.5.4-stable.xml']
# ClickHouse-21.1.6.13-stable.xml
# ClickHouse-21.1.6.13-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.1.6.13-stable.zip', '-o', 'ClickHouse-21.1.6.13-stable.xml']
# ClickHouse-21.1.8.30-stable.xml
# ClickHouse-21.1.8.30-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.1.8.30-stable.zip', '-o', 'ClickHouse-21.1.8.30-stable.xml']
# ClickHouse-21.1.9.41-stable.xml
# ClickHouse-21.1.9.41-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.1.9.41-stable.zip', '-o', 'ClickHouse-21.1.9.41-stable.xml']
# ClickHouse-21.10.4.26-stable.xml
# ClickHouse-21.10.4.26-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.10.4.26-stable.zip', '-o', 'ClickHouse-21.10.4.26-stable.xml']
# ClickHouse-21.10.5.3-stable.xml
# ClickHouse-21.10.5.3-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.10.5.3-stable.zip', '-o', 'ClickHouse-21.10.5.3-stable.xml']
# ClickHouse-21.10.6.2-stable.xml
# ClickHouse-21.10.6.2-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.10.6.2-stable.zip', '-o', 'ClickHouse-21.10.6.2-stable.xml']
# ClickHouse-21.11.10.1-stable.xml
# ClickHouse-21.11.10.1-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.11.10.1-stable.zip', '-o', 'ClickHouse-21.11.10.1-stable.xml']
# ClickHouse-21.11.11.1-stable.xml
# ClickHouse-21.11.11.1-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.11.11.1-stable.zip', '-o', 'ClickHouse-21.11.11.1-stable.xml']
# ClickHouse-21.11.5.33-stable.xml
# ClickHouse-21.11.5.33-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.11.5.33-stable.zip', '-o', 'ClickHouse-21.11.5.33-stable.xml']
# ClickHouse-21.11.6.7-stable.xml
# ClickHouse-21.11.6.7-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.11.6.7-stable.zip', '-o', 'ClickHouse-21.11.6.7-stable.xml']
# ClickHouse-21.11.7.9-stable.xml
# ClickHouse-21.11.7.9-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.11.7.9-stable.zip', '-o', 'ClickHouse-21.11.7.9-stable.xml']
# ClickHouse-21.11.8.4-stable.xml
# ClickHouse-21.11.8.4-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.11.8.4-stable.zip', '-o', 'ClickHouse-21.11.8.4-stable.xml']
# ClickHouse-21.12.2.17-stable.xml
# ClickHouse-21.12.2.17-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.12.2.17-stable.zip', '-o', 'ClickHouse-21.12.2.17-stable.xml']
# ClickHouse-21.12.3.32-stable.xml
# ClickHouse-21.12.3.32-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.12.3.32-stable.zip', '-o', 'ClickHouse-21.12.3.32-stable.xml']
# ClickHouse-21.12.4.1-stable.xml
# ClickHouse-21.12.4.1-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.12.4.1-stable.zip', '-o', 'ClickHouse-21.12.4.1-stable.xml']
# ClickHouse-21.2.10.48-stable.xml
# ClickHouse-21.2.10.48-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.2.10.48-stable.zip', '-o', 'ClickHouse-21.2.10.48-stable.xml']
# ClickHouse-21.2.2.8-stable.xml
# ClickHouse-21.2.2.8-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.2.2.8-stable.zip', '-o', 'ClickHouse-21.2.2.8-stable.xml']
# ClickHouse-21.2.3.15-stable.xml
# ClickHouse-21.2.3.15-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.2.3.15-stable.zip', '-o', 'ClickHouse-21.2.3.15-stable.xml']
# ClickHouse-21.2.4.6-stable.xml
# ClickHouse-21.2.4.6-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.2.4.6-stable.zip', '-o', 'ClickHouse-21.2.4.6-stable.xml']
# ClickHouse-21.2.5.5-stable.xml
# ClickHouse-21.2.5.5-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.2.5.5-stable.zip', '-o', 'ClickHouse-21.2.5.5-stable.xml']
# ClickHouse-21.2.6.1-stable.xml
# ClickHouse-21.2.6.1-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.2.6.1-stable.zip', '-o', 'ClickHouse-21.2.6.1-stable.xml']
# ClickHouse-21.2.8.31-stable.xml
# ClickHouse-21.2.8.31-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.2.8.31-stable.zip', '-o', 'ClickHouse-21.2.8.31-stable.xml']
# ClickHouse-21.2.9.41-stable(1).xml
# ClickHouse-21.2.9.41-stable(1).zip
# ['srcml', '--verbose', 'ClickHouse-21.2.9.41-stable(1).zip', '-o', 'ClickHouse-21.2.9.41-stable(1).xml']
# ClickHouse-21.2.9.41-stable.xml
# ClickHouse-21.2.9.41-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.2.9.41-stable.zip', '-o', 'ClickHouse-21.2.9.41-stable.xml']
# ClickHouse-21.3.14.1-lts.xml
# ClickHouse-21.3.14.1-lts.zip
# ['srcml', '--verbose', 'ClickHouse-21.3.14.1-lts.zip', '-o', 'ClickHouse-21.3.14.1-lts.xml']
# ClickHouse-21.3.19.1-lts.xml
# ClickHouse-21.3.19.1-lts.zip
# ['srcml', '--verbose', 'ClickHouse-21.3.19.1-lts.zip', '-o', 'ClickHouse-21.3.19.1-lts.xml']
# ClickHouse-21.4.3.21-stable(1).xml
# ClickHouse-21.4.3.21-stable(1).zip
# ['srcml', '--verbose', 'ClickHouse-21.4.3.21-stable(1).zip', '-o', 'ClickHouse-21.4.3.21-stable(1).xml']
# ClickHouse-21.4.3.21-stable.xml
# ClickHouse-21.4.3.21-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.4.3.21-stable.zip', '-o', 'ClickHouse-21.4.3.21-stable.xml']
# ClickHouse-21.4.4.30-stable.xml
# ClickHouse-21.4.4.30-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.4.4.30-stable.zip', '-o', 'ClickHouse-21.4.4.30-stable.xml']
# ClickHouse-21.4.7.3-stable.xml
# ClickHouse-21.4.7.3-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.4.7.3-stable.zip', '-o', 'ClickHouse-21.4.7.3-stable.xml']
# ClickHouse-21.5.5.12-stable.xml
# ClickHouse-21.5.5.12-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.5.5.12-stable.zip', '-o', 'ClickHouse-21.5.5.12-stable.xml']
# ClickHouse-21.5.6.6-stable.xml
# ClickHouse-21.5.6.6-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.5.6.6-stable.zip', '-o', 'ClickHouse-21.5.6.6-stable.xml']
# ClickHouse-21.5.7.9-stable.xml
# ClickHouse-21.5.7.9-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.5.7.9-stable.zip', '-o', 'ClickHouse-21.5.7.9-stable.xml']
# ClickHouse-21.5.8.21-stable.xml
# ClickHouse-21.5.8.21-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.5.8.21-stable.zip', '-o', 'ClickHouse-21.5.8.21-stable.xml']
# ClickHouse-21.5.9.4-stable.xml
# ClickHouse-21.5.9.4-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.5.9.4-stable.zip', '-o', 'ClickHouse-21.5.9.4-stable.xml']
# ClickHouse-21.6.6.51-stable.xml
# ClickHouse-21.6.6.51-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.6.6.51-stable.zip', '-o', 'ClickHouse-21.6.6.51-stable.xml']
# ClickHouse-21.6.7.57-stable.xml
# ClickHouse-21.6.7.57-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.6.7.57-stable.zip', '-o', 'ClickHouse-21.6.7.57-stable.xml']
# ClickHouse-21.7.1.7029-testing.xml
# ClickHouse-21.7.1.7029-testing.zip
# ['srcml', '--verbose', 'ClickHouse-21.7.1.7029-testing.zip', '-o', 'ClickHouse-21.7.1.7029-testing.xml']
# ClickHouse-21.7.10.4-stable.xml
# ClickHouse-21.7.10.4-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.7.10.4-stable.zip', '-o', 'ClickHouse-21.7.10.4-stable.xml']
# ClickHouse-21.7.11.3-stable.xml
# ClickHouse-21.7.11.3-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.7.11.3-stable.zip', '-o', 'ClickHouse-21.7.11.3-stable.xml']
# ClickHouse-21.7.4.18-stable.xml
# ClickHouse-21.7.4.18-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.7.4.18-stable.zip', '-o', 'ClickHouse-21.7.4.18-stable.xml']
# ClickHouse-21.7.5.29-stable.xml
# ClickHouse-21.7.5.29-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.7.5.29-stable.zip', '-o', 'ClickHouse-21.7.5.29-stable.xml']
# ClickHouse-21.7.6.39-stable.xml
# ClickHouse-21.7.6.39-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.7.6.39-stable.zip', '-o', 'ClickHouse-21.7.6.39-stable.xml']
# ClickHouse-21.7.9.7-stable.xml
# ClickHouse-21.7.9.7-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.7.9.7-stable.zip', '-o', 'ClickHouse-21.7.9.7-stable.xml']
# ClickHouse-21.8.6.15-lts.xml
# ClickHouse-21.8.6.15-lts.zip
# ['srcml', '--verbose', 'ClickHouse-21.8.6.15-lts.zip', '-o', 'ClickHouse-21.8.6.15-lts.xml']
# ClickHouse-21.9.2.17-stable.xml
# ClickHouse-21.9.2.17-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.9.2.17-stable.zip', '-o', 'ClickHouse-21.9.2.17-stable.xml']
# ClickHouse-21.9.6.24-stable.xml
# ClickHouse-21.9.6.24-stable.zip
# ['srcml', '--verbose', 'ClickHouse-21.9.6.24-stable.zip', '-o', 'ClickHouse-21.9.6.24-stable.xml']
# ClickHouse-22.1.2.2-stable.xml
# ClickHouse-22.1.2.2-stable.zip
# ['srcml', '--verbose', 'ClickHouse-22.1.2.2-stable.zip', '-o', 'ClickHouse-22.1.2.2-stable.xml']
# ClickHouse-22.1.3.7-stable.xml
# ClickHouse-22.1.3.7-stable.zip
# ['srcml', '--verbose', 'ClickHouse-22.1.3.7-stable.zip', '-o', 'ClickHouse-22.1.3.7-stable.xml']
